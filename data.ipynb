# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("./Data/telecom_customer_churn.csv")

# %%
df
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0     0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1     0003-MKNFE    Male   46      No                     0      Glendale
# 2     0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3     0011-IGKFF    Male   78     Yes                     0      Martinez
# 4     0013-EXCHZ  Female   75     Yes                     0     Camarillo
# ...          ...     ...  ...     ...                   ...           ...
# 7038  9987-LUTYD  Female   20      No                     0       La Mesa
# 7039  9992-RRAMN    Male   40     Yes                     0     Riverbank
# 7040  9992-UJOEL    Male   22      No                     0           Elk
# 7041  9993-LHIEB    Male   21     Yes                     0  Solana Beach
# 7042  9995-HOTOH    Male   36     Yes                     0   Sierra City
#
#       Zip Code   Latitude   Longitude  Number of Referrals  ...  \
# ...

# %%
try:
    dic = pd.read_csv('./Data/telecom_data_dictionary.csv', encoding='latin1')
except UnicodeDecodeError:
    dic = pd.read_csv('./Data/telecom_data_dictionary.csv', encoding='cp1252')
dic
# Out:
#                   Table                              Field  \
# 0        Customer Churn                         CustomerID
# 1        Customer Churn                             Gender
# 2        Customer Churn                                Age
# 3        Customer Churn                            Married
# 4        Customer Churn               Number of Dependents
# 5        Customer Churn                               City
# 6        Customer Churn                           Zip Code
# 7        Customer Churn                           Latitude
# 8        Customer Churn                          Longitude
# 9        Customer Churn                Number of Referrals
# 10       Customer Churn                   Tenure in Months
# 11       Customer Churn                              Offer
# 12       Customer Churn                      Phone Service
# 13       Customer Churn  Avg Monthly Long Distance Charges
# 14       Customer Churn                     Multiple Lines
# ...

# %%
df
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0     0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1     0003-MKNFE    Male   46      No                     0      Glendale
# 2     0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3     0011-IGKFF    Male   78     Yes                     0      Martinez
# 4     0013-EXCHZ  Female   75     Yes                     0     Camarillo
# ...          ...     ...  ...     ...                   ...           ...
# 7038  9987-LUTYD  Female   20      No                     0       La Mesa
# 7039  9992-RRAMN    Male   40     Yes                     0     Riverbank
# 7040  9992-UJOEL    Male   22      No                     0           Elk
# 7041  9993-LHIEB    Male   21     Yes                     0  Solana Beach
# 7042  9995-HOTOH    Male   36     Yes                     0   Sierra City
#
#       Zip Code   Latitude   Longitude  Number of Referrals  ...  \
# ...

# %% [markdown]
# variables a tener en cuenta para el modelo:
# X
# age, number of dependents(lo excluimos porque tiene 70% ceros),zip code, tenure of months, phone service, internet service, multiple lines, device protection plan, monthly charge,total refunds, total long distance charges,
#
# Y
# target: customer status

# %%
df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'Married', 'Number of Dependents',
#        'City', 'Zip Code', 'Latitude', 'Longitude', 'Number of Referrals',
#        'Tenure in Months', 'Offer', 'Phone Service',
#        'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Customer Status', 'Churn Category', 'Churn Reason'],
#       dtype='object')

# %%
dfml=df[['Age','Number of Dependents','Zip Code', 'Tenure in Months', 'Phone Service', 'Internet Service', 'Multiple Lines', 'Device Protection Plan', 'Monthly Charge','Total Refunds', 'Total Long Distance Charges','Customer Status']]

# %%
df['Customer Status'].unique()
# Out:
# array(['Stayed', 'Churned', 'Joined'], dtype=object)

# %%
df['Customer Status'].value_counts()
# Out:
# Customer Status
# Stayed     4720
# Churned    1869
# Joined      454
# Name: count, dtype: int64

# %% [markdown]
# buscamos abandonos por género

# %%
df.loc[(df['Gender']=='Female') & (df['Customer Status']=='Churned')].shape
# Out:
# (939, 38)

# %%
df.loc[(df['Gender']=='Male') & (df['Customer Status']=='Churned')].shape
# Out:
# (930, 38)

# %% [markdown]
# entonces como los resultados son similares no tomamos la variable 'Gender' para el modelo

# %%
matriz_correlacion = dfml.corr()
import seaborn as sns
import matplotlib.pyplot as plt

# Crear un mapa de calor de la matriz de correlación
sns.heatmap(matriz_correlacion, annot=True, cmap='coolwarm')

# Mostrar el mapa de calor
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 matriz_correlacion = dfml.corr()
#       2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
#
# File c:\Users\agus_\miniconda3\envs\myenv\lib\site-packages\pandas\core\frame.py:11036, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11034 cols = data.columns
#   11035 idx = cols.copy()
# > 11036 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11038 if method == "pearson":
#   11039     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\agus_\miniconda3\envs\myenv\lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# -> 1981 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %% [markdown]
# Decidimos hacer una regresión logística ya que es clasificación.

# %% [markdown]
# extraemos la columna 'Internet Service' porque decidimos analizar los futuros abandonos de los clientes que contratan servicio telefónico

# %%
dfmlx=df[['Age','Number of Dependents','Zip Code', 'Tenure in Months', 'Phone Service', 'Multiple Lines', 'Device Protection Plan', 'Monthly Charge','Total Refunds', 'Total Long Distance Charges']]

# %%
dfmlx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          7043 non-null   int64
#  1   Number of Dependents         7043 non-null   int64
#  2   Zip Code                     7043 non-null   int64
#  3   Tenure in Months             7043 non-null   int64
#  4   Phone Service                7043 non-null   object
#  5   Multiple Lines               6361 non-null   object
#  6   Device Protection Plan       5517 non-null   object
#  7   Monthly Charge               7043 non-null   float64
#  8   Total Refunds                7043 non-null   float64
#  9   Total Long Distance Charges  7043 non-null   float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 550.4+ KB

# %%
dfmlx[['Phone Service', 'Multiple Lines','Device Protection Plan']] = dfmlx[['Phone Service', 'Multiple Lines','Device Protection Plan']].replace({'Yes': 1, 'No': 0})
# Out:
# C:\Users\agus_\AppData\Local\Temp\ipykernel_45416\1242797384.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dfmlx[['Phone Service', 'Multiple Lines','Device Protection Plan']] = dfmlx[['Phone Service', 'Multiple Lines','Device Protection Plan']].replace({'Yes': 1, 'No': 0})
# C:\Users\agus_\AppData\Local\Temp\ipykernel_45416\1242797384.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_dummies = pd.get_dummies(df, columns=['Customer Status'])
df_dummies['Customer Status_Stayed']=df_dummies['Customer Status_Stayed']+df_dummies['Customer Status_Joined']
dfmly=df_dummies['Customer Status_Stayed']

# %%
dfmlx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          7043 non-null   int64
#  1   Number of Dependents         7043 non-null   int64
#  2   Zip Code                     7043 non-null   int64
#  3   Tenure in Months             7043 non-null   int64
#  4   Phone Service                7043 non-null   int64
#  5   Multiple Lines               6361 non-null   float64
#  6   Device Protection Plan       5517 non-null   float64
#  7   Monthly Charge               7043 non-null   float64
#  8   Total Refunds                7043 non-null   float64
#  9   Total Long Distance Charges  7043 non-null   float64
# dtypes: float64(5), int64(5)
# memory usage: 550.4 KB

# %%
dfmlx.fillna(0, inplace=True)
# Out:
# C:\Users\agus_\AppData\Local\Temp\ipykernel_45416\2964165279.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmlx.fillna(0, inplace=True)

# %%
matriz_correlacion = dfmlx.corr()


# Crear un mapa de calor de la matriz de correlación
sns.heatmap(matriz_correlacion, annot=True, cmap='coolwarm')

# Mostrar el mapa de calor
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       1 matriz_correlacion = dfmlx.corr()
#       4 # Crear un mapa de calor de la matriz de correlación
# ----> 5 sns.heatmap(matriz_correlacion, annot=True, cmap='coolwarm')
#       7 # Mostrar el mapa de calor
#       8 plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# Modelo:

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


# Separar características y etiquetas
X = dfmlx
y = dfmly

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Crear el modelo
model = LogisticRegression()

# Entrenar el modelo
model.fit(X_train, y_train)

# Hacer predicciones con el conjunto de prueba
y_pred = model.predict(X_test)

# Calcular la exactitud
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)

# Reporte de clasificación
class_report = classification_report(y_test, y_pred)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 0.7893989588263133
# Confusion Matrix:
# [[ 239  312]
#  [ 133 1429]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.64      0.43      0.52       551
#         True       0.82      0.91      0.87      1562
#
#     accuracy                           0.79      2113
#    macro avg       0.73      0.67      0.69      2113
# weighted avg       0.77      0.79      0.77      2113

# %%
dfmlx=df[['Age','Number of Dependents','Zip Code', 'Tenure in Months', 'Phone Service', 'Multiple Lines', 'Device Protection Plan', 'Monthly Charge','Total Refunds', 'Total Long Distance Charges','Offer']]
dfmlx[['Phone Service', 'Multiple Lines','Device Protection Plan']] = dfmlx[['Phone Service', 'Multiple Lines','Device Protection Plan']].replace({'Yes': 1, 'No': 0})
dfmlx.fillna(0, inplace=True)
# Out:
# C:\Users\agus_\AppData\Local\Temp\ipykernel_45416\3001677474.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dfmlx[['Phone Service', 'Multiple Lines','Device Protection Plan']] = dfmlx[['Phone Service', 'Multiple Lines','Device Protection Plan']].replace({'Yes': 1, 'No': 0})
# C:\Users\agus_\AppData\Local\Temp\ipykernel_45416\3001677474.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
dfmlx['Offer'].unique()
# Out:
# array([0, 'Offer E', 'Offer D', 'Offer A', 'Offer B', 'Offer C'],
#       dtype=object)

# %%
dfmlx['Offer'] = dfmlx['Offer'].replace({'None': 0, 'Offer A': 1,'Offer B': 1,'Offer C': 1,'Offer D': 1,'Offer E': 1})
# Out:
# C:\Users\agus_\AppData\Local\Temp\ipykernel_45416\1758455988.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dfmlx['Offer'] = dfmlx['Offer'].replace({'None': 0, 'Offer A': 1,'Offer B': 1,'Offer C': 1,'Offer D': 1,'Offer E': 1})
# C:\Users\agus_\AppData\Local\Temp\ipykernel_45416\1758455988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmlx['Offer'] = dfmlx['Offer'].replace({'None': 0, 'Offer A': 1,'Offer B': 1,'Offer C': 1,'Offer D': 1,'Offer E': 1})

# %%
# Separar características y etiquetas
X = dfmlx
y = dfmly

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Crear el modelo
model_f = LogisticRegression()

# Entrenar el modelo
model_f.fit(X_train, y_train)

# Hacer predicciones con el conjunto de prueba
y_pred = model.predict(X_test)

# Calcular la exactitud
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)

# Reporte de clasificación
class_report = classification_report(y_test, y_pred)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 0.7950780880265026
# Confusion Matrix:
# [[ 284  267]
#  [ 166 1396]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.63      0.52      0.57       551
#         True       0.84      0.89      0.87      1562
#
#     accuracy                           0.80      2113
#    macro avg       0.74      0.70      0.72      2113
# weighted avg       0.79      0.80      0.79      2113
# c:\Users\agus_\miniconda3\envs\myenv\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# acá concluimos si el cliente ha aceptado una oferta, no es garantía de retención.

# %% [markdown]
# Probamos cambiar la columna "Zip Code" por "North" para indicar si cada cliente es del norte o no.

# %%
df['North'] = df['Latitude'].apply(lambda x: 1 if x >= 34 else 0)

# %%
dfmlx['North'] = df['North'].values
# Out:
# C:\Users\agus_\AppData\Local\Temp\ipykernel_45416\3235940814.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmlx['North'] = df['North'].values

# %%
dfmlx.head()
# Out:
#    Age  Number of Dependents  Zip Code  Tenure in Months  Phone Service  \
# 0   37                     0     93225                 9              1
# 1   46                     0     91206                 9              1
# 2   50                     0     92627                 4              1
# 3   78                     0     94553                13              1
# 4   75                     0     93010                 3              1
#
#    Multiple Lines  Device Protection Plan  Monthly Charge  Total Refunds  \
# 0             0.0                     0.0            65.6           0.00
# 1             1.0                     0.0            -4.0          38.33
# 2             0.0                     1.0            73.9           0.00
# 3             0.0                     1.0            98.0           0.00
# 4             0.0                     0.0            83.9           0.00
#
#    Total Long Distance Charges  Offer  North
# 0                       381.51      0      1
# ...

# %%
dfmlx.drop(columns='Zip Code', inplace= True)
# Out:
# C:\Users\agus_\AppData\Local\Temp\ipykernel_45416\1048346838.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmlx.drop(columns='Zip Code', inplace= True)

# %%
#def rlmodelo(datasetX):
# Separar características y etiquetas
X = dfmlx
y = dfmly
# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Crear el modelo
model_rl = LogisticRegression()
# Entrenar el modelo
model_rl.fit(X_train, y_train)
# Hacer predicciones con el conjunto de prueba
y_pred = model.predict(X_test)
# Calcular la exactitud
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)
# Reporte de clasificación
class_report = classification_report(y_test, y_pred)
print('Classification Report:')
y_score = model.predict_proba(X_test)
# Out:
# Accuracy: 0.7950780880265026
# Confusion Matrix:
# [[ 284  267]
#  [ 166 1396]]
# Classification Report:
# c:\Users\agus_\miniconda3\envs\myenv\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
X_test.to_csv('x_test.csv', index=False)

# %% [markdown]
# El modelo mejoró al cambiar Zip Code por North.

# %%
numero_registro = 3825
registro = df_dummies.iloc[numero_registro]
print(registro)
# Out:
# Customer ID                           5377-NDTOU
# Gender                                    Female
# Age                                           26
# Married                                      Yes
# Number of Dependents                           0
# City                                   San Pedro
# Zip Code                                   90732
# Latitude                               33.744119
# Longitude                             -118.31448
# Number of Referrals                            3
# Tenure in Months                              71
# Offer                                    Offer A
# Phone Service                                Yes
# Avg Monthly Long Distance Charges            9.5
# Multiple Lines                               Yes
# Internet Service                             Yes
# Internet Type                              Cable
# Avg Monthly GB Download                     76.0
# Online Security                              Yes
# ...

# %% [markdown]
# Probamos sacar la edad, pero vimos que el modelo empeoraba.

# %% [markdown]
# volvemos a incorporar la columna "Age"

# %% [markdown]
# Ahora probaremos agregando la columna "Internet Service"

# %%
dfmlx['Internet Service'] = df['Internet Service'].values
dfmlx['Internet Service'] = dfmlx['Internet Service'].replace({'Yes': 1, 'No': 0})
dfmlx.fillna(0, inplace=True)
# Out:
# C:\Users\agus_\AppData\Local\Temp\ipykernel_45416\2943822870.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmlx['Internet Service'] = df['Internet Service'].values
# C:\Users\agus_\AppData\Local\Temp\ipykernel_45416\2943822870.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dfmlx['Internet Service'] = dfmlx['Internet Service'].replace({'Yes': 1, 'No': 0})
# C:\Users\agus_\AppData\Local\Temp\ipykernel_45416\2943822870.py:2: SettingWithCopyWarning:
# ...

# %%
dfmlx.head()
# Out:
#    Age  Number of Dependents  Tenure in Months  Phone Service  Multiple Lines  \
# 0   37                     0                 9              1             0.0
# 1   46                     0                 9              1             1.0
# 2   50                     0                 4              1             0.0
# 3   78                     0                13              1             0.0
# 4   75                     0                 3              1             0.0
#
#    Device Protection Plan  Monthly Charge  Total Refunds  \
# 0                     0.0            65.6           0.00
# 1                     0.0            -4.0          38.33
# 2                     1.0            73.9           0.00
# 3                     1.0            98.0           0.00
# 4                     0.0            83.9           0.00
#
#    Total Long Distance Charges  Offer  North  Internet Service
# 0                       381.51      0      1                 1
# ...

# %%
X = dfmlx
y = dfmly

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Crear el modelo
model_rl = LogisticRegression()
# Entrenar el modelo
model_rl.fit(X_train, y_train)
# Hacer predicciones con el conjunto de prueba
y_pred = model.predict(X_test)
# Calcular la exactitud
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)
# Reporte de clasificación
class_report = classification_report(y_test, y_pred)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 0.7950780880265026
# Confusion Matrix:
# [[ 284  267]
#  [ 166 1396]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.63      0.52      0.57       551
#         True       0.84      0.89      0.87      1562
#
#     accuracy                           0.80      2113
#    macro avg       0.74      0.70      0.72      2113
# weighted avg       0.79      0.80      0.79      2113
# c:\Users\agus_\miniconda3\envs\myenv\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Recordamos que buscamos reducir la cantidad de falsos positivos, ya que esto indicaría que un cliente se queda cuando en realidad se va.

# %% [markdown]
# Queda por comparar con otros modelos distinto al del regresión logística.

# %%
from sklearn.ensemble import RandomForestClassifier

# Separar características y etiquetas
X = dfmlx
y = dfmly

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Crear el modelo de Random Forest
model_rf = RandomForestClassifier(n_estimators=100, random_state=42)

# Entrenar el modelo
model_rf.fit(X_train, y_train)

# Hacer predicciones con el conjunto de prueba
y_pred = model.predict(X_test)

# Calcular la exactitud
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)

# Reporte de clasificación
class_report = classification_report(y_test, y_pred)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 0.7950780880265026
# Confusion Matrix:
# [[ 284  267]
#  [ 166 1396]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.63      0.52      0.57       551
#         True       0.84      0.89      0.87      1562
#
#     accuracy                           0.80      2113
#    macro avg       0.74      0.70      0.72      2113
# weighted avg       0.79      0.80      0.79      2113

# %%
from sklearn.tree import DecisionTreeClassifier


# Suponiendo que dfmlx y dfmly ya están definidos como tus características y etiquetas
X = dfmlx
y = dfmly

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Crear el modelo de árbol de decisión con parámetros ajustados
model_t = DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=42)

# Entrenar el modelo
model_t.fit(X_train, y_train)

# Hacer predicciones con el conjunto de prueba
y_pred = model.predict(X_test)

# Calcular la exactitud
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')

# Matriz de confusión
conf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(conf_matrix)

# Reporte de clasificación
class_report = classification_report(y_test, y_pred)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 0.7950780880265026
# Confusion Matrix:
# [[ 284  267]
#  [ 166 1396]]
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.63      0.52      0.57       551
#         True       0.84      0.89      0.87      1562
#
#     accuracy                           0.80      2113
#    macro avg       0.74      0.70      0.72      2113
# weighted avg       0.79      0.80      0.79      2113

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
train_dict = dfmlx.to_dict(orient='records')

# %%
train_dict[2]
# Out:
# {'Age': 50,
#  'Number of Dependents': 0,
#  'Tenure in Months': 4,
#  'Phone Service': 1,
#  'Multiple Lines': 0.0,
#  'Device Protection Plan': 1.0,
#  'Monthly Charge': 73.9,
#  'Total Refunds': 0.0,
#  'Total Long Distance Charges': 134.6,
#  'Offer': 1,
#  'North': 0,
#  'Internet Service': 1}

# %%
dv = DictVectorizer(sparse=False)
dv.fit(train_dict)
# Out:
# DictVectorizer(sparse=False)

# %%
X_train = dv.transform(train_dict)

# %%
import pickle

# %%
with open('model_C=1.0.bin', 'wb') as f_out:
   pickle.dump((dv, model_rl), f_out)
   f_out.close()

# %%
df_X_test = pd.DataFrame(X_test, columns=X_test.columns)

# %%
for index, row in X_test.iterrows():
    row_reshaped = row.values.reshape(1, -1)
    prediction = model_rl.predict(row_reshaped)
    result = prediction[0] == 1
    print(f"Fila {index}: Predicción = {result}")
# Out:
# c:\Users\agus_\miniconda3\envs\myenv\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\agus_\miniconda3\envs\myenv\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\agus_\miniconda3\envs\myenv\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\agus_\miniconda3\envs\myenv\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\agus_\miniconda3\envs\myenv\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# ...

# %%
dfmlx.iloc[185]
dfmlx.dtypes
# Out:
# Age                              int64
# Number of Dependents             int64
# Tenure in Months                 int64
# Phone Service                    int64
# Multiple Lines                 float64
# Device Protection Plan         float64
# Monthly Charge                 float64
# Total Refunds                  float64
# Total Long Distance Charges    float64
# Offer                            int64
# North                            int64
# Internet Service                 int64
# dtype: object

# %%
customer = {
"Age":78,
"Tenure in Months": 2,
"Total Refunds": 0,
"Number of Dependents": 3,
"Phone Service": 1,
"Multiple Lines": 1,
"Internet Service": 0,
"Device Protection Plan": 0,
"Monthly Charge": 0,
"Total Long Distance Charges": 0,
"Offer": 0,
"North": 0
}

# %%
X_test = dv.transform([customer])
model_rl.predict(X_test)
# Out:
# c:\Users\agus_\miniconda3\envs\myenv\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([False])
